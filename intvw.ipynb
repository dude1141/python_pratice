# %% [markdown]
# <a href="https://colab.research.google.com/github/dude1141/python_pratice/blob/main/intvw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d='/content/logstest.txt'
import re
with open(d ,'r') as file:
  f=file.readlines()
  # g=f.strip()
c=0
y=0
b=""
errolines = [i for i in f]
for j in errolines:
  j=j.split(" ")
  # print("j",j)
  print(j)
  c=c+1
  for p in j:
    if p == '[ERROR]':
      y =y+1
      b=p.replace("["," ").replace("]"," ")

  print(b)
  print(y)
# Out:
# ['2024-07-01', '10:02:15', '[INFO]', 'System', 'started\n']
#
# 0
# ['2024-07-01', '10:05:22', '[ERROR]', 'Failed', 'to', 'load', 'config\n']
#  ERROR
# 1
# ['2024-07-01', '10:07:30', '[WARNING]', 'Low', 'memory\n']
#  ERROR
# 1
# ['2024-07-01', '10:10:45', '[ERROR]', 'Connection', 'timeout']
#  ERROR
# 2

# %% [markdown]
# # New Section

# %%
d='/content/logstest.txt'
import re
with open(d ,'r') as file:
  i=file.readlines()

#using list comprehension
errolines = [i for i in i if '[ERROR]' in i]
errolines
# Out:
# ['2024-07-01 10:05:22 [ERROR] Failed to load config\n',
#  '2024-07-01 10:10:45 [ERROR] Connection timeout']

# %%
#recursion


# def facts(x):
#   if x==0:
#     print("fact is 1")
#   elif x==1:
#     print("fact is 0")
#   else:
#     f = facts(x - 1) * x
#     # f=facts(x-1) * x
#     return f

def facts(x):
  if x==0:
    return 1
    print("fact is 1")
  elif x==1:
    return 1
    print("fact is 0")
  else:
    f = facts(x - 1) * x
    # f=facts(x-1) * x
    return f

#just add return
facts(5)
# Out:
# 120

# %%
# %%bigquery
#
#  CREATE TABLE IF NOT EXISTS users (
#         id INTEGER PRIMARY KEY,
#         name TEXT,
#         age INTEGER
#     )
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=262006177488-ka1m0ue4fptfmt9siejdd5lom7p39upa.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fpydata-google-auth.readthedocs.io%2Fen%2Flatest%2Foauth.html&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform&state=4stYhcBZr9UhhxOtqRqsSkK9j3XQVa&code_challenge=bToRPX_flazsL9H-NyvCBkkiAMRIyAFIBDrXuaXUv00&code_challenge_method=S256&prompt=consent&access_type=offline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10667/3771001507.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bigquery', '', '\n CREATE TABLE IF NOT EXISTS users (\n        id INTEGER PRIMARY KEY,\n        name TEXT,\n        age INTEGER\n    )\n')
#
# ...

# %%
#fibonnaci series

def fibb(x):
  if x <= 1:
    return x
  return fibb(x - 1) + fibb(x - 2)

  #formulae is n-1 +n-2

print(fibb(8))
# Out:
# 21

# %%
# x='Apppple Apple'
# print(x[0][0])
# create function to check two chars of string

def checkchar(x):
  # x1 = input("string:")
  x2 = x.split(" ")
  if x2[0][0] == x2[1][0]:
    print("true")
  else:
    print('False')


checkchar('plazy lrazy')
# Out:
# False

# %%
#lists load everything in memory upfront
#generators  lazy evaluation uses yield, provide continous stream without memory build up.prevent memory spikes and pipeline firendly
#Iterators  sequential access to data
#

def read(x):
  with open file as n:
    for i in n:
      yeild i

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = ["scala","java","python","sheeet"]

#reverse and capitalize firstletter
a=[]
for i in range (len(data)-1,-1,-1):
  # print(data[i])
  # a.append(data[i])
  # print(a)
  # x = data[i]
  # x =x[0].upper() + x[1:]
  # a.append(x)
  # print(a)
  a.append(data[i][0].upper()+data[i][1:])
  print(a)
# Out:
# ['Sheeet']
# ['Sheeet', 'Python']
# ['Sheeet', 'Python', 'Java']
# ['Sheeet', 'Python', 'Java', 'Scala']

# %%
data = ["scala","java","python","sheeet"]

for i in range(0,len(data),1):
  print(i,data[i])
# Out:
# 0 scala
# 1 java
# 2 python
# 3 sheeet

# %%
alist=[1,3,4,6,8,8,10]

a=[]

# b=[i for i in alist.count(i)]
# print(b)

# [expression for item in iterable].

# res = [i for i in b if alist.count(i) >1 ]

# {key: value for item in list}

res = {i: alist.count(i) for i in alist}
print(res)
# Out:
# {1: 1, 3: 1, 4: 1, 6: 1, 8: 2, 10: 1}

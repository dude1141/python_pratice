# %% [markdown]
# <a href="https://colab.research.google.com/github/dude1141/python_pratice/blob/main/intvw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d='/content/logstest.txt'
import re
with open(d ,'r') as file:
  f=file.readlines()
  # g=f.strip()
c=0
y=0
b=""
errolines = [i for i in f]
for j in errolines:
  j=j.split(" ")
  # print("j",j)
  print(j)
  c=c+1
  for p in j:
    if p == '[ERROR]':
      y =y+1
      b=p.replace("["," ").replace("]"," ")

  print(b)
  print(y)
# Out:
# ['2024-07-01', '10:02:15', '[INFO]', 'System', 'started\n']
#
# 0
# ['2024-07-01', '10:05:22', '[ERROR]', 'Failed', 'to', 'load', 'config\n']
#  ERROR
# 1
# ['2024-07-01', '10:07:30', '[WARNING]', 'Low', 'memory\n']
#  ERROR
# 1
# ['2024-07-01', '10:10:45', '[ERROR]', 'Connection', 'timeout']
#  ERROR
# 2

# %% [markdown]
# # New Section

# %%
d='/content/logstest.txt'
import re
with open(d ,'r') as file:
  i=file.readlines()

#using list comprehension
errolines = [i for i in i if '[ERROR]' in i]
errolines
# Out:
# ['2024-07-01 10:05:22 [ERROR] Failed to load config\n',
#  '2024-07-01 10:10:45 [ERROR] Connection timeout']

# %%
#recursion


def facts(x):
  if x==0:
    print("fact is 1")
  elif x==1:
    print("fact is 0")
  else:
    f=x*facts(x-1)
    print(f)

facts(5)
# Out:
# fact is 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10667/706817097.py in <cell line: 0>()
#      11     print(f)
#      12
# ---> 13 facts(5)
#
# /tmp/ipykernel_10667/706817097.py in facts(x)
#       8     print("fact is 0")
#       9   else:
# ---> 10     f=x*facts(x-1)
#      11     print(f)
#      12
#
# /tmp/ipykernel_10667/706817097.py in facts(x)
#       8     print("fact is 0")
#       9   else:
# ---> 10     f=x*facts(x-1)
#      11     print(f)
#      12
#
# /tmp/ipykernel_10667/706817097.py in facts(x)
#       8     print("fact is 0")
#       9   else:
# ---> 10     f=x*facts(x-1)
#      11     print(f)
#      12
#
# /tmp/ipykernel_10667/706817097.py in facts(x)
#       8     print("fact is 0")
#       9   else:
# ---> 10     f=x*facts(x-1)
#      11     print(f)
#      12
#
# TypeError: unsupported operand type(s) for *: 'int' and 'NoneType'

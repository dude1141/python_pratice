# %%
#Ref from ankitbansal tutorials

# %%
# !pip install kaggle

# %%
# download from kaggle to local download folder
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
#extract a zipefile , using zipfile.Zipfile

import zipfile
with zipfile.ZipFile("orders.csv.zip", "r")  as zipref:
    zipref.extractall()

# %%
import pandas as pd

data =pd.read_csv('orders.csv',na_values=['Not Available','unknown','null'])
# data.head(5)
# data

data['Ship Mode'].unique()
# data['Ship Mode'].unique().na_values('Not Available','unknown',null)
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
data['Ship Mode'].unique()
# data['Ship Mode'].unique().na_values('Not Available','unknown',null)
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#handling notavialble and unknown using na_values
df =pd.read_csv('orders.csv',na_values=['Not Available','unknown'])
# data.head(5)
# data

df['Ship Mode'].unique()

# %%
#rename columns
# df.rename(columns={})
# df.columns returns a index Object
data.columns =data.columns.str.lower().str.replace(' ','_')
# df2 =df1.columns.replace(' ','_')
# df.columns = df.columns.replace(' ','_')
data

# df.columns
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
#derive new columns discount, saleprice and profit

data['discount']= data['list_price']*data['discount_percent']*.01

# df[listprice*discount_percent*.01
data['saleprice']=data['list_price']-data['discount']
data['profit'] =data['saleprice']-data['cost_price']
# df.type()
#profit = saleice -costprice

# %%
data.dtypes

data['order_date']= pd.to_datetime(data['order_date'],format="%Y-%m-%d")
data.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# sub_category                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# discount                   float64
# saleprice                  float64
# profit                     float64
# dtype: object

# %%
data.drop(columns=['list_price','cost_price','discount_percent'],inplace= True)

# %%
# !pip install pymysql
# Out:
# ...
#   Obtaining dependency information for pymysql from https://files.pythonhosted.org/packages/8e/dc/9085f3d6f497e9b25fb40d6e8ecef3ddbb5cf977a949b933624a299f5c16/pymysql-1.1.3-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/45.4 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.4 kB ? eta -:--:--
#    ------------------ --------------------- 20.5/45.4 kB 217.9 kB/s eta 0:00:01
#    ---------------------------------------- 45.4/45.4 kB 373.6 kB/s eta 0:00:00
# ...

# %%
import pandas as pdf
from sqlalchemy import create_engine 
cnx = create_engine("mysql+pymysql://root:root@localhost:3306/tables")    
df = pd.read_sql("SELECT * FROM employees",cnx)
df
# Out:
#     emp_id emp_name  dept_id  manager_id  salary   hire_date  \
# 0        1     John       10         NaN   90000  2018-01-10
# 1        2     Sara       10         1.0   70000  2019-03-15
# 2        3     Amit       20         5.0   60000  2020-05-20
# 3        4     Lina       30         1.0   75000  2017-09-11
# 4        5      Raj       20         NaN   95000  2016-12-05
# 5        6      Dev       30         1.0   72000  2021-04-18
# 6        7      Kim       10         1.0   50000  2022-02-02
# 7        8     Jill       20         5.0   85000  2019-07-22
# 8        9    rohit       20         5.0   90000  2019-07-23
# 9       10    kunal       20         5.0  100000  2019-07-24
# 10      11       RK       20         5.0  110000  2016-12-04
# 11       5      Raj       30         NaN   95000  2016-12-05
#
#                job_title
# 0                Manager
# 1              Developer
# 2              Developer
# 3                Analyst
# 4                Manager
# ...

# %%
#load data in tomysql
df.to_sql('df_orders',con=cnx,index=False,if_exists='replace')
# Out:
# 12
